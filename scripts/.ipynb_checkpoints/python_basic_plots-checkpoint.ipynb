# %%
iris = sns.load_dataset("iris")

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.shape
# Out:
# (150, 5)

# %%
fig, ax= plt.subplots(1,2,figsize=(12,6))
iris.plot(kind='box', ax=ax[0], title='with pandas')
sns.boxplot(data=iris, ax=ax[1])
plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/box_plot.png'
plt.savefig(savefn)

# %%
fig, ax= plt.subplots(figsize=(5,5))
sns.boxplot(x='species', y='sepal_length', data=iris)

# Calculate number of obs per group & median to position labels
medians = iris.groupby(['species'])['sepal_length'].median().values
maxs = iris.groupby(['species'])['sepal_length'].max().values
means = iris.groupby(['species'])['sepal_length'].mean().values
nobs = iris['species'].value_counts().values
nobs = [str(x) for x in nobs.tolist()]
nobs = ["n: " + i for i in nobs]

# add the number of observations on the top
pos = range(len(nobs))
for tick,label in zip(pos,ax.get_xticklabels()):
    ax.text(pos[tick], medians[tick] + 0.03, nobs[tick],
            horizontalalignment='center', size='x-small', color='w', weight='semibold')
    
    ax.text(pos[tick], maxs[tick] + 0.03, nobs[tick],
            horizontalalignment='center', size='x-small', color='black', weight='semibold')
    
    ax.text(pos[tick], 8 + 0.03, nobs[tick],
            horizontalalignment='center', size='x-small', color='black', weight='semibold')

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/box_plot2.png'
plt.savefig(savefn)

# %%
fig, ax = plt.subplots(1, 3, figsize=(12,4))
sns.boxplot( x="species", y="sepal_length", data=iris, linewidth=5, ax=ax[0])
sns.boxplot( x="species", y="sepal_length", data=iris, notch=True, ax=ax[1])
sns.boxplot( x="species", y="sepal_length", data=iris, width=0.3, ax=ax[2])
ax[0].set(title='control line width')
ax[1].set(title='add notch')
ax[2].set(title='control box width')
plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/box_plot3.png'
plt.savefig(savefn)

# %%
fig, ax= plt.subplots(figsize=(5,5))
ax = sns.boxplot(x='species', y='sepal_length', data=iris)
ax = sns.swarmplot(x='species', y='sepal_length', data=iris, color="grey")
plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/box_plot4.png'
plt.savefig(savefn)

# %%
df = sns.load_dataset('tips')
print df.head()

fig, ax= plt.subplots(figsize=(5,5))
sns.boxplot(x="day", y="total_bill", hue="smoker", data=df, palette="Set1")

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/box_plot5.png'
plt.savefig(savefn)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df = sns.load_dataset('tips')
print df.head()

fig, ax= plt.subplots(figsize=(5,5))
sns.pointplot(x="total_bill", y="tip", data=df, linestyles='', )

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/scatter_plot1.png'
plt.savefig(savefn)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
fig, ax= plt.subplots(figsize=(5,5))
df.plot(kind='scatter', x='total_bill', y='tip', ax=ax)

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/scatter_plot1.png'
plt.savefig(savefn)

# %%
plt.plot(x=list(df['total_bill']), y=list(df['tip']))
# Out:
# []

# %%
fig, ax= plt.subplots(figsize=(5,5))
plt.scatter(x=df['total_bill'], y=df['tip'])

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/scatter_plot1.png'
plt.savefig(savefn)

# %%
df2=pd.DataFrame({'x': range(1,10), 'y': np.random.randn(9)*80+range(1,10) })
plt.plot( 'x', 'y', data=df2, linestyle='-', marker='o')
# Out:
# /Users/gongjing/usr/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:3261: RuntimeWarning: Second argument 'y' is ambiguous: could be a color spec but is in data. Using as data.
# Either rename the entry in data or use three arguments to plot.
#   ret = ax.plot(*args, **kwargs)

# %%
df2=pd.DataFrame({'x': range(1,10), 'y': np.random.randn(9)*80+range(1,10) })

with sns.set_style(axis='ticks'):
    fig, ax= plt.subplots(1,2, figsize=(10,5))

df2.plot(ax=ax[0], x='x', y='y',linestyle='-', marker='o')
sns.pointplot(x='x', y='y', data=df2, ax=ax[1])

plt.tight_layout()
savefn = '/Users/gongjing/Dropbox/blog_codes/images/scatter_plot2.png'
plt.savefig(savefn)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-c246c4104a8d> in <module>()
#       1 df2=pd.DataFrame({'x': range(1,10), 'y': np.random.randn(9)*80+range(1,10) })
#       2
# ----> 3 with sns.set_style(axis='ticks'):
#       4     fig, ax= plt.subplots(1,2, figsize=(10,5))
#       5
#
# TypeError: set_style() got an unexpected keyword argument 'axis'

# %%
f = '/Users/gongjing/Dropbox/HotDuplex-files/clipdb_human.protein_entry_stat.txt'

# %%
d = pd.read_csv(f, header=0, sep='\t')
d['# of entry (merged)'] = d['# of entry (before)'] - d['# of entry (after)']
d
# Out:
#     # of entry (before) protein (before)  # of entry (after) protein (after)  \
# 0                 15674           ALKBH5               14589          ALKBH5
# 1                430144            ATXN2              275801           ATXN2
# 2                 27025         C17orf85               25873        C17orf85
# 3                 97634          CAPRIN1               88492         CAPRIN1
# 4                 85231            CPSF1               72225           CPSF1
# 5                 17148            CPSF2               15240           CPSF2
# 6                 97201            CPSF3               91742           CPSF3
# 7                 64184            CPSF4               59694           CPSF4
# 8                357114            CPSF6              203206           CPSF6
# 9                407396            CPSF7              301164           CPSF7
# 10              1383374            CSTF2              882079           CSTF2
# ...

# %%
plt.bar(x=d['protein (before)'], y=d['# of entry (after)'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-72d21752f3bc> in <module>()
# ----> 1 plt.bar(x=d['protein (before)'], y=d['# of entry (after)'])
#
# /Users/gongjing/usr/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.pyc in bar(*args, **kwargs)
#    2646                       mplDeprecation)
#    2647     try:
# -> 2648         ret = ax.bar(*args, **kwargs)
#    2649     finally:
#    2650         ax._hold = washold
#
# /Users/gongjing/usr/anaconda2/lib/python2.7/site-packages/matplotlib/__init__.pyc in inner(ax, *args, **kwargs)
#    1715                     warnings.warn(msg % (label_namer, func.__name__),
#    1716                                   RuntimeWarning, stacklevel=2)
# -> 1717             return func(ax, *args, **kwargs)
#    1718         pre_doc = inner.__doc__
#    1719         if pre_doc is None:
#
# ...

# %%
dd = d.groupby(['protein (before)','# of entry (after)']).count()['protein (after)']

# %%
dd
# Out:
# protein (before)  # of entry (after)
# ALKBH5            14589                 1
# ATXN2             275801                1
# C17orf85          25873                 1
# CAPRIN1           88492                 1
# CPSF1             72225                 1
# CPSF2             15240                 1
# CPSF3             91742                 1
# CPSF4             59694                 1
# CPSF6             203206                1
# CPSF7             301164                1
# CSTF2             882079                1
# CSTF2T            493841                1
# DGCR8             6543                  1
# EIF4A3            17552                 1
# ELAVL1            1552164               1
# EWSR1             75227                 1
# EZH2              164                   1
# FBL               7095                  1
# FIP1L1            406403                1
# FMR1              131968                1
# FUS               245670                1
# ...

# %%
dd.index.get_level_values(0)
# Out:
# Index([u'ALKBH5', u'ATXN2', u'C17orf85', u'CAPRIN1', u'CPSF1', u'CPSF2',
#        u'CPSF3', u'CPSF4', u'CPSF6', u'CPSF7', u'CSTF2', u'CSTF2T', u'DGCR8',
#        u'EIF4A3', u'ELAVL1', u'EWSR1', u'EZH2', u'FBL', u'FIP1L1', u'FMR1',
#        u'FUS', u'FXR1', u'FXR2', u'HNRNPA1', u'HNRNPA2B1', u'HNRNPC',
#        u'HNRNPD', u'HNRNPF', u'HNRNPH', u'HNRNPM', u'HNRNPU', u'IGF2BP1',
#        u'IGF2BP2', u'IGF2BP3', u'LIN28A', u'LIN28B', u'METTL14', u'METTL3',
#        u'MOV10', u'NOP56', u'NOP58', u'NUDT21', u'PTBP1', u'PTBP1PTBP2',
#        u'PUM2', u'QKI', u'RBM10', u'RBM47', u'RBPMS', u'RTCB', u'SRRM4',
#        u'TAF15', u'TARBP2', u'TARDBP', u'TIA1', u'TIAL1', u'TNRC6A', u'TNRC6B',
#        u'TNRC6C', u'U2AF2', u'UPF1', u'WDR33', u'WTAP', u'YTHDF2', u'ZC3H7B'],
#       dtype='object', name=u'protein (before)')

# %%
# ?pd.read_csv

# %%
f = '/Users/gongjing/Dropbox/HotDuplex-files/RBP_annotations.csv'

# %%
d = pd.read_csv(f, header=0, sep='\t', index_col=0)
d
# Out:
#                ALKBH5  ATXN2  C17orf85  CAPRIN1  CPSF1  CPSF2  CPSF3  CPSF4  \
# gene
# nucleus             1    NaN         1      NaN      1      1      1      1
# cytoplasm         NaN      1       NaN        1    NaN    NaN    NaN    NaN
# stablize          NaN    NaN       NaN      NaN    NaN    NaN    NaN    NaN
# destablize        NaN    NaN       NaN      NaN    NaN    NaN    NaN    NaN
# single strand       1      1         1        1      1      1      1      1
# double strand     NaN    NaN       NaN      NaN    NaN    NaN    NaN    NaN
#
#                CPSF6  CPSF7   ...    TIAL1  TNRC6A  TNRC6B  TNRC6C  U2AF2  \
# gene                          ...
# nucleus            1      1   ...        1       1     NaN     NaN      1
# cytoplasm        NaN    NaN   ...      NaN       1       1       1    NaN
# stablize         NaN    NaN   ...      NaN     NaN     NaN     NaN    NaN
# destablize       NaN    NaN   ...      NaN     NaN     NaN     NaN    NaN
# ...

# %%
d.replace(np.nan, 0, inplace=True)

# %%
d
# Out:
#                ALKBH5  ATXN2  C17orf85  CAPRIN1  CPSF1  CPSF2  CPSF3  CPSF4  \
# gene
# nucleus             1      0         1        0      1      1      1      1
# cytoplasm           0      1         0        1      0      0      0      0
# stablize            0      0         0        0      0      0      0      0
# destablize          0      0         0        0      0      0      0      0
# single strand       1      1         1        1      1      1      1      1
# double strand       0      0         0        0      0      0      0      0
#
#                CPSF6  CPSF7   ...    TIAL1  TNRC6A  TNRC6B  TNRC6C  U2AF2  \
# gene                          ...
# nucleus            1      1   ...        1       1       0       0      1
# cytoplasm          0      0   ...        0       1       1       1      0
# stablize           0      0   ...        0       0       0       0      0
# destablize         0      0   ...        0       0       0       0      0
# ...

# %%
fig,ax = plt.subplots(figsize=(40,40))
sns.heatmap(d, annot=False, linewidths=0.5, square=True, ax=ax, cbar=False, vmax=2)
plt.savefig('/Users/gongjing/Dropbox/HotDuplex-files/RBP_annotations.png')

# %%
df = pd.DataFrame({'5UTR':[np.nan, np.nan, np.nan, np.nan, np.nan], 
              'Exon':[0,1,0,0,0], 
              'CDS':[3,0,474,5,0], 
              'Intron':[0,0,2,0,0], 
              '3UTR':[0,0,8,0,5]})
type_order = ['5UTR', 'Exon', 'CDS', 'Intron', '3UTR']
df.index = type_order
df = df.loc[type_order, type_order]

# %%
df
# Out:
#         5UTR  Exon  CDS  Intron  3UTR
# 5UTR     NaN     0    3       0     0
# Exon     NaN     1    0       0     0
# CDS      NaN     0  474       2     8
# Intron   NaN     0    5       0     0
# 3UTR     NaN     0    0       0     5

# %%
df_T = df.T
df_T
# Out:
#         5UTR  Exon  CDS  Intron  3UTR
# 5UTR     NaN   NaN  NaN     NaN   NaN
# Exon       0     1    0       0     0
# CDS        3     0  474       5     0
# Intron     0     0    2       0     0
# 3UTR       0     0    8       0     5

# %%
np.fill_diagonal(df_T.values, 0)

# %%
df_T
# Out:
#         5UTR  Exon  CDS  Intron  3UTR
# 5UTR       0   NaN  NaN     NaN   NaN
# Exon       0     0    0       0     0
# CDS        3     0    0       5     0
# Intron     0     0    2       0     0
# 3UTR       0     0    8       0     0

# %%
df + df_T
# Out:
#         5UTR  Exon  CDS  Intron  3UTR
# 5UTR     NaN   NaN  NaN     NaN   NaN
# Exon     NaN     1    0       0     0
# CDS      NaN     0  474       7     8
# Intron   NaN     0    7       0     0
# 3UTR     NaN     0    8       0     5

# %%
fig, ax = plt.subplots(1,2)
ax[1].plot([1,2,3],[4,5,6],color='red', label='ss', marker='o', ls='-.')
ax[1].legend()

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('ticks')

# %matplotlib inline

# %%
np.random.random(42)
X = np.random.exponential(size=1000)
X_norm_min_max = (X - X.min()) / (X.max() - X.min())
X_norm_mean_max = (X - X.mean()) / (X.max() - X.min())
X_norm_zscore = (X - X.mean()) / X.std()
X_norm_unit = X / np.linalg.norm(X)

# %%
fig, ax = plt.subplots(3, 2, figsize=(16,18), sharex=False, sharey=False)
sns.distplot(X, ax=ax[0,0])
ax[0,0].set_title('Raw')
sns.distplot(X_norm_min_max, ax=ax[0,1])
ax[0,1].set_title('min-max norm')
sns.distplot(X_norm_mean_max, ax=ax[1,0])
ax[1,0].set_title('mean-max norm')
sns.distplot(X_norm_zscore, ax=ax[1,1])
ax[1,1].set_title('z-score norm')
sns.distplot(X_norm_unit, ax=ax[2,0])
ax[2,0].set_title('unit length norm')
# Out:
# Text(0.5,1,'unit length norm')

# %%
# Out:
# 42.07161077661015
